# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/WG-lstmcrf-2.0')

# %%
# requirements
# !pip install transformers
# !pip install overrides

# %% [markdown]
# Prepare the dataset:

# %%
# preprocess the dataset
# !python filter_words.py

# %% [markdown]
# Tune and train the model:

# %%
# using gpu
# !python trainer.py --dataset=POI_ext --num_epochs=15 --model_folder=POI_model_e15_hd256_ext --device=cuda:0 --hidden_dim=256

# %%
# using gpu
# !python trainer.py --dataset=street_ext --num_epochs=18 --model_folder=street_model_e18_hd256_ext --device=cuda:0 --hidden_dim=256
# Out:
# 2021-03-19 17:52:10.695224: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# device: cuda:0
# seed: 42
# dataset: street_ext
# embedding_file: data/embeddings.txt
# embedding_dim: 100
# optimizer: sgd
# learning_rate: 0.01
# l2: 1e-08
# lr_decay: 0
# batch_size: 10
# num_epochs: 18
# train_num: -1
# dev_num: -1
# test_num: -1
# max_no_incre: 100
# model_folder: street_model_e18_hd256_ext
# hidden_dim: 256
# dropout: 0.5
# use_char_rnn: 1
# static_context_emb: none
# add_iobes_constraint: 0
# reading the pretraing embedding: data/embeddings.txt
# [Warning] pretrain embedding file not exists, using random embedding
# using GPU... 0
# [Data Info] Reading dataset from:
# data/street_ext/train.txt
# data/street_ext/dev.txt
# data/street_ext/test.txt
# [Data Info] Reading file: data/street_ext/train.txt, labels will be converted to IOBES encoding
# ...

# %% [markdown]
# If you don't have GPU, run the code below:

# %%
# !python trainer.py --dataset=POI_ext --num_epochs=15 --model_folder=POI_model_e15_hd256_ext --device=cpu --hidden_dim=256

# %%
# !python trainer.py --dataset=street_ext --num_epochs=15 --model_folder=street_model_e15_hd256_ext --device=cpu --hidden_dim=256

# %% [markdown]
# Generate the final results:

# %%
# combine the predictions
# modify --poi and --street to the results you got from previous training
# !combine_filter.py --poi=POI_model_e12_hd256_ext.results --street=street_model_e18_hd256_ext.results

# %%
# check the gpu version
import torch
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'
